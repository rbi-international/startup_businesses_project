# %%
import pandas as pd

# %%
df = pd.read_csv('startup_funding.csv')
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
#sorted(df['Startup Name'].unique().tolist())

# %%
#df['Investors Name'] = df['Investors Name'].fillna('Undisclosed')

# %%
#sorted(df['Investors Name'].unique().tolist())

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.drop(columns=['Remarks'], inplace=True)

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD
# 0    Tiger Global Management  Private Equity Round  20,00,00,000
# ...

# %%
df.set_index('Sr No', inplace=True)

# %%
df.head()
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
#
#                                  SubVertical City  Location  \
# Sr No
# 1                                 E-learning      Bengaluru
# 2                  App based shuttle service        Gurgaon
# 3      Retailer of baby and toddler products      Bengaluru
# 4                          Online Investment      New Delhi
# 5                Embroiled Clothes For Women         Mumbai
#
#                   Investors Name       InvestmentnType Amount in USD
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000
# ...

# %%
df.rename(columns = {
    'Date dd/mm/yyyy' : 'date',
    'Startup Name' : 'startup',
    'Industry Vertical' : 'vertical',
    'SubVertical' : 'subvertical',
    'City  Location' : 'city',
    'Investors Name' : 'investors',
    'InvestmentnType' : 'round',
    'Amount in USD' : 'amount',
    
},inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investors',
#        'round', 'amount'],
#       dtype='object')

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round        amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount'] = df['amount'].fillna('0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount'] = df['amount'].str.replace(',','')

# %%
df['amount'] = df['amount'].str.replace('undisclosed','0')

# %%
df['amount'] = df['amount'].str.replace('unknown','0')

# %%
df['amount'] = df['amount'].str.replace('Undisclosed','0')

# %%
df = df[df['amount'].str.isdigit()]

# %%
df['amount'] = df['amount'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   object
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 213.0+ KB

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0
# ...

# %%
# create a function to convert dollar amount into crore rupees
def to_inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['amount'] = df['amount'].apply(to_inr)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df['date'] = df['date'].replace({'05/072018':'05/07/2018', '01/07/015': '01/07/2015', '22/01//2015': '22/01/2015'})

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3025 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df = df.dropna(subset=['date', 'startup', 'vertical', 'city', 'investors', 'round', 'amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2820 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2820 non-null   datetime64[ns]
#  1   startup      2820 non-null   object
#  2   vertical     2820 non-null   object
#  3   subvertical  2078 non-null   object
#  4   city         2820 non-null   object
#  5   investors    2820 non-null   object
#  6   round        2820 non-null   object
#  7   amount       2820 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 198.3+ KB

# %%
df.to_csv('startup_funding_cleaned.csv', index = False)

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['investors'].str.contains('IDG Ventures')].head()[['date', 'startup', 'vertical', 'city', 'round', 'amount']]
# Out:
#             date   startup           vertical       city           round  \
# Sr No
# 102   2019-04-13   Tripoto       Social Media  New Delhi        Series B
# 223   2018-07-30  Cure Fit  Consumer Internet  Bengaluru  Private Equity
# 259   2018-05-02   Bizongo  Consumer Internet     Mumbai  Private Equity
# 310   2018-04-26     POPxo         Technology      Delhi  Private Equity
# 439   2017-12-07   eShakti          Ecommerce    Chennai    Debt Funding
#
#            amount
# Sr No
# 102     29.628844
# 223    990.000000
# 259    181.500000
# 310     45.375000
# 439     18.975000

# %%
df[df['investors'].str.contains('IDG Ventures')].groupby('startup')['amount'].sum().sort_values(ascending=False)
# Out:
# startup
# Cure Fit                 990.000000
# Lenskart                 495.000000
# Bizongo                  206.250000
# CureFit                  206.250000
# Curefit                  123.750000
# Fintellix                123.750000
# Xpressbees               103.125000
# FirstCry.com              82.500000
# Uniphore                  72.600000
# POPxo                     70.950000
# HealthifyMe               49.500000
# \\xc2\\xa0CloudCherry     49.500000
# Sigtuple                  47.850000
# Flyrobe                   43.725000
# RentMojo                  41.250000
# Aasaanjobs                41.250000
# Vayana                    33.000000
# Agrostar                  33.000000
# PlaySimple                33.000000
# Blowhorn                  30.112500
# Tripoto                   29.628844
# Active.ai                 24.750000
# Heckyl                    22.275000
# CreditMantri              20.625000
# eShakti                   18.975000
# Zimmber                   16.500000
# ...

# %%
import matplotlib.pyplot as plt

# %%
df[df['investors'].str.contains('Sequoia India')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains('Sequoia India')].groupby('round')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains('Sequoia India')].groupby('city')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df['year'] = df['date'].dt.year

# %%
df.head(2)
# Out:
#             date startup        vertical                subvertical  \
# Sr No
# 1     2020-01-09  BYJU’S          E-Tech                 E-learning
# 2     2020-01-13  Shuttl  Transportation  App based shuttle service
#
#             city                  investors                 round      amount  \
# Sr No
# 1      Bengaluru    Tiger Global Management  Private Equity Round  1650.00000
# 2        Gurgaon  Susquehanna Growth Equity              Series C    66.39925
#
#        year
# Sr No
# 1      2020
# 2      2020

# %%
df[df['investors'].str.contains('Sequoia India')].groupby('year')['amount'].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
import pandas as pd
df1 = pd.read_csv('startup_funding_cleaned.csv')    
df1.head()
# Out:
#          date                       startup             vertical  \
# 0  2020-01-09                        BYJU’S               E-Tech
# 1  2020-01-13                        Shuttl       Transportation
# 2  2020-01-09                     Mamaearth           E-commerce
# 3  2020-01-02  https://www.wealthbucket.in/              FinTech
# 4  2020-01-02                        Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors                 round       amount
# 0    Tiger Global Management  Private Equity Round  1650.000000
# 1  Susquehanna Growth Equity              Series C    66.399250
# 2      Sequoia Capital India              Series B   151.460595
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2820 entries, 0 to 2819
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2820 non-null   object
#  1   startup      2820 non-null   object
#  2   vertical     2820 non-null   object
#  3   subvertical  2078 non-null   object
#  4   city         2820 non-null   object
#  5   investors    2820 non-null   object
#  6   round        2820 non-null   object
#  7   amount       2820 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 176.4+ KB

# %%
df1['date'] = pd.to_datetime(df1['date'], errors='coerce')

# %%
df1['year'] = df1['date'].dt.year

# %%
df1.head()
# Out:
#         date                       startup             vertical  \
# 0 2020-01-09                        BYJU’S               E-Tech
# 1 2020-01-13                        Shuttl       Transportation
# 2 2020-01-09                     Mamaearth           E-commerce
# 3 2020-01-02  https://www.wealthbucket.in/              FinTech
# 4 2020-01-02                        Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors                 round       amount  year
# 0    Tiger Global Management  Private Equity Round  1650.000000  2020
# 1  Susquehanna Growth Equity              Series C    66.399250  2020
# ...

# %%
# create a function to Find similar investors names and their company names
def find_investor(investor):
    return df1[df1['investors'].str.contains(investor, case=False)]['startup'].unique()
find_investor('Sequoia')
# Out:
# array(['Mamaearth', 'Freshworks', 'FPL Technologies', 'Progcap', 'Moglix',
#        'BlackBuck', 'CleverTap', 'Zilingo', 'CarDekho', 'Blackbuck',
#        'Samosa Labs', 'Metro Bikes', 'Five Star Group', 'Meesho',
#        'Daily Ninja', 'Drip capital', 'WickedRide', '1mg', 'Urban Ladder',
#        'Finova Capital', 'Rupeek', 'happay', 'Capillary', 'HomeLane',
#        'Zefo', 'RAW Pressery', 'OncoStem', 'OYO Rooms', 'Unacademy',
#        'Dhruva', 'MedGenome', 'Increff', 'MoneyTap', 'OneAssist',
#        'Faasos', 'Oyo Rooms', 'Awfis', 'Belong', 'Ixigo', 'Voonik',
#        'CueMath', 'Pocket Aces', 'FreshDesk', 'Zarget', 'Vymo',
#        'Knowlarity', 'HelpChat', 'DailyHunt', 'Kredx', 'Mad Street Den',
#        'Byju\\\\xe2\\\\x80\\\\x99s', 'Druva', 'HealthKart', 'Flyrobe',
#        'PressPlay TV', 'SirionLabs', 'Capital Float', 'Cleartax', 'Oyo',
#        'B9 Beverages', 'CREO', 'Shuttl', 'Chillr', 'MobiKwik',
#        'CraftsVilla', 'Grofers', 'Grabhouse', 'Citrus Payment',
# ...

# %%
df1['amount'].sum()
# Out:
# 296476.36866375

# %%
df['amount'].sum()
# Out:
# 296476.36866375

# %%
df['amount'].max()
# Out:
# 32175.0

# %%
df[df['amount'] == df['amount'].max()]
# Out:
#             date           startup        vertical subvertical       city  \
# Sr No
# 61    2019-08-27  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#                 investors     round   amount  year
# Sr No
# 61     Westbridge Capital  Series B  32175.0  2019

# %%
df.groupby('startup')['amount'].max().sort_values(ascending=False).head(1).values[0]
# Out:
# 32175.0

# %%
df.groupby('startup')['amount'].sum().mean()
# Out:
# 129.01495590241515

# %%
df['startup'].nunique()
# Out:
# 2298

# %%
# MoM chart -> Total + Count
df['month'] = df['date'].dt.month

# %%
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-01-09                     Mamaearth                  E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/                     FinTech
# 5     2020-01-02                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
temp_df = df.groupby(['year', 'month'])['amount'].count().reset_index()

# %%
temp_df['x_axis'] = temp_df['month'].astype('str') + '-' + temp_df['year'].astype('str')

# %%
temp_df
# Out:
#     year  month  amount   x_axis
# 0   2015      4      61   4-2015
# 1   2015      5      55   5-2015
# 2   2015      6      84   6-2015
# 3   2015      7      86   7-2015
# 4   2015      8      98   8-2015
# 5   2015      9      87   9-2015
# 6   2015     10      93  10-2015
# 7   2015     11      90  11-2015
# 8   2015     12      88  12-2015
# 9   2016      1     104   1-2016
# 10  2016      2      99   2-2016
# 11  2016      3      84   3-2016
# 12  2016      4      77   4-2016
# 13  2016      5      79   5-2016
# 14  2016      6      97   6-2016
# 15  2016      7      63   7-2016
# 16  2016      8      87   8-2016
# 17  2016      9      73   9-2016
# 18  2016     10      80  10-2016
# 19  2016     11      72  11-2016
# 20  2016     12      72  12-2016
# 21  2017      1      72   1-2017
# 22  2017      2      48   2-2017
# 23  2017      3      71   3-2017
# 24  2017      4      71   4-2017
# 25  2017      5      67   5-2017
# 26  2017      6      65   6-2017
# ...

# %%
temp_df[['amount', 'x_axis']]
# Out:
#     amount   x_axis
# 0       61   4-2015
# 1       55   5-2015
# 2       84   6-2015
# 3       86   7-2015
# 4       98   8-2015
# 5       87   9-2015
# 6       93  10-2015
# 7       90  11-2015
# 8       88  12-2015
# 9      104   1-2016
# 10      99   2-2016
# 11      84   3-2016
# 12      77   4-2016
# 13      79   5-2016
# 14      97   6-2016
# 15      63   7-2016
# 16      87   8-2016
# 17      73   9-2016
# 18      80  10-2016
# 19      72  11-2016
# 20      72  12-2016
# 21      72   1-2017
# 22      48   2-2017
# 23      71   3-2017
# 24      71   4-2017
# 25      67   5-2017
# 26      65   6-2017
# 27      42   7-2017
# 28      45   8-2017
# 29      58   9-2017
# 30      53  10-2017
# 31      50  11-2017
# 32      42  12-2017
# 33      36   1-2018
# 34      42   2-2018
# 35      33   3-2018
# 36      32   4-2018
# 37      22   5-2018
# 38      32   6-2018
# 39      34   7-2018
# 40      21   8-2018
# 41      12   9-2018
# 42       7  10-2018
# 43      18  11-2018
# ...

# %%
df.groupby(['year', 'month'])['amount'].count().reset_index()
# Out:
#     year  month  amount
# 0   2015      4      61
# 1   2015      5      55
# 2   2015      6      84
# 3   2015      7      86
# 4   2015      8      98
# 5   2015      9      87
# 6   2015     10      93
# 7   2015     11      90
# 8   2015     12      88
# 9   2016      1     104
# 10  2016      2      99
# 11  2016      3      84
# 12  2016      4      77
# 13  2016      5      79
# 14  2016      6      97
# 15  2016      7      63
# 16  2016      8      87
# 17  2016      9      73
# 18  2016     10      80
# 19  2016     11      72
# 20  2016     12      72
# 21  2017      1      72
# 22  2017      2      48
# 23  2017      3      71
# 24  2017      4      71
# 25  2017      5      67
# 26  2017      6      65
# 27  2017      7      42
# 28  2017      8      45
# 29  2017      9      58
# 30  2017     10      53
# 31  2017     11      50
# 32  2017     12      42
# 33  2018      1      36
# 34  2018      2      42
# 35  2018      3      33
# 36  2018      4      32
# ...
